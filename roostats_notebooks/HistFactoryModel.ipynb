// %% [markdown]
// ## HistFactory Model
//
// Create a counting model but using the HistFactory (i.e. an histogram with a single bin)

// %%
using namespace RooFit;
using namespace RooStats;
using namespace RooStats::HistFactory;
        
int nobs;
double b; 
double sigmab;

// %%
   nobs = 3;
    b = 1;
    sigmab = 0.1;
    TH1D * hobs = new TH1D("hobs","hobs",1,0,1);
   hobs->SetBinContent(1,nobs); 


   TH1D * h1_s = new TH1D("hs","signal  histo",1,0,1);
   h1_s->SetBinContent(1,1);

   
   TH1D * h1_b = new TH1D("hb","bkg  histo",1,0,1);
   h1_b->SetBinContent(1,b);

// %%
 RooStats::HistFactory::Measurement meas("CountingModel","CountingModel");
   meas.SetPOI("mu");

   meas.SetLumi(1.0);
   meas.SetLumiRelErr(0.001);  // not relevant 
   // this does not make lumi varying
   meas.AddConstantParam("Lumi");

   RooStats::HistFactory::Channel channel("SignalRegion"); 
   channel.SetData(hobs);

   RooStats::HistFactory::Sample signalSample("signal");
   signalSample.AddNormFactor("mu",1,0,30);
   //signalSample.AddOverallSys("sig_unc",0.99, 1.01);
   signalSample.SetHisto(h1_s); 
   channel.AddSample(signalSample);

   RooStats::HistFactory::Sample backgSample("background");
   //backg.AddNormFactor("taub",b,0,10);
   backgSample.SetHisto(h1_b);
   backgSample.AddOverallSys("b_unc",1.-sigmab, 1+sigmab);  // b uncertainty
   channel.AddSample(backgSample);

meas.AddChannel(channel);
// Out:
// RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
//                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
//                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

// %% [markdown]
//  make the model and save in a file

// %%
   RooWorkspace * w = RooStats::HistFactory::MakeModelAndMeasurementFast(meas);

   // to change interpolation mode to piecewise linear (default is type=4, polynomial interp + exp. exytrapolation)
   RooStats::HistFactory::FlexibleInterpVar * fl = (RooStats::HistFactory::FlexibleInterpVar *) w->function("background_SignalRegion_epsilon");
   if (fl) fl->setAllInterpCodes(0);
   else printf("ERROR changing interp code \n");
   
   w->writeToFile("HistFactoryModel.root",true);
// Out:
// Making Model and Measurements (Fast) for measurement: CountingModel
// using lumi = 1 and lumiError = 0.001 including bins between 0 and 1
// fixing the following parameters:
//    Lumi
// Creating the output file: _CountingModel.root
// Creating the table file: _results.table
// Creating the HistoToWorkspaceFactoryFast factory
// Setting preprocess functions
// Starting to process channel: SignalRegion
//
//
// -------------------
// Starting to process SignalRegion channel with 1 observables
// lumi str = [1,0,10]
// lumi Error str = nominalLumi[1,0,1.01],0.001
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing RooConstVar::signal_SignalRegion_epsilon
// making normFactor: mu
// signal_SignalRegion has no variation histograms
// processing hist hs
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing dataset signal_SignalRegionnominalDHist
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing RooHistFunc::signal_SignalRegion_nominal
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing RooStats::HistFactory::FlexibleInterpVar::background_SignalRegion_epsilon
// background_SignalRegion has no variation histograms
// processing hist hb
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing dataset background_SignalRegionnominalDHist
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing RooHistFunc::background_SignalRegion_nominal
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing RooRealSumPdf::SignalRegion_model
// -----------------------------------------
// import model into workspace
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooGaussian::lumiConstraint for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooConstVar::0.001 for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::Lumi for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::nominalLumi for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooGaussian::alpha_b_uncConstraint for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooConstVar::1 for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::alpha_b_unc for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::nom_alpha_b_unc for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealSumPdf::SignalRegion_model for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooProduct::L_x_signal_SignalRegion_overallSyst_x_Exp for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooProduct::signal_SignalRegion_overallSyst_x_Exp for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooHistFunc::signal_SignalRegion_nominal for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::obs_x_SignalRegion for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooProduct::signal_SignalRegion_overallNorm_x_sigma_epsilon for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::mu for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooConstVar::signal_SignalRegion_epsilon for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::binWidth_obs_x_SignalRegion_0 for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooProduct::L_x_background_SignalRegion_overallSyst_x_Exp for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooProduct::background_SignalRegion_overallSyst_x_Exp for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooHistFunc::background_SignalRegion_nominal for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooStats::HistFactory::FlexibleInterpVar::background_SignalRegion_epsilon for import of RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) using existing copy of RooRealVar::binWidth_obs_x_SignalRegion_1 for import of RooProdPdf::model_SignalRegion
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// RooDataSet::AsimovData[obs_x_SignalRegion,weight:binWeightAsimov] = 1 entries (2 weighted)
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing dataset AsimovData
// [#1] INFO:ObjectHandling -- RooWorkSpace::import(SignalRegion) changing name of dataset from  AsimovData to asimovData
// [#1] INFO:ObjectHandling -- RooWorkspace::import(SignalRegion) importing dataset obsData
//
// RooWorkspace(SignalRegion) SignalRegion workspace contents
//
// variables
// ---------
// (Lumi,alpha_b_unc,binWidth_obs_x_SignalRegion_0,binWidth_obs_x_SignalRegion_1,mu,nom_alpha_b_unc,nominalLumi,obs_x_SignalRegion,weightVar)
//
// p.d.f.s
// -------
// RooRealSumPdf::SignalRegion_model[ binWidth_obs_x_SignalRegion_0 * L_x_signal_SignalRegion_overallSyst_x_Exp + binWidth_obs_x_SignalRegion_1 * L_x_background_SignalRegion_overallSyst_x_Exp ] = 2/2
// RooGaussian::alpha_b_uncConstraint[ x=alpha_b_unc mean=nom_alpha_b_unc sigma=1 ] = 1
// RooGaussian::lumiConstraint[ x=Lumi mean=nominalLumi sigma=0.001 ] = 1
// RooProdPdf::model_SignalRegion[ lumiConstraint * alpha_b_uncConstraint * SignalRegion_model(obs_x_SignalRegion) ] = 2
//
// functions
// --------
// RooProduct::L_x_background_SignalRegion_overallSyst_x_Exp[ Lumi * background_SignalRegion_overallSyst_x_Exp ] = 1
// RooProduct::L_x_signal_SignalRegion_overallSyst_x_Exp[ Lumi * signal_SignalRegion_overallSyst_x_Exp ] = 1
// RooStats::HistFactory::FlexibleInterpVar::background_SignalRegion_epsilon[ paramList=(alpha_b_unc) ] = 1
// RooHistFunc::background_SignalRegion_nominal[ depList=(obs_x_SignalRegion) ] = 1
// RooProduct::background_SignalRegion_overallSyst_x_Exp[ background_SignalRegion_nominal * background_SignalRegion_epsilon ] = 1
// RooHistFunc::signal_SignalRegion_nominal[ depList=(obs_x_SignalRegion) ] = 1
// RooProduct::signal_SignalRegion_overallNorm_x_sigma_epsilon[ mu * signal_SignalRegion_epsilon ] = 1
// RooProduct::signal_SignalRegion_overallSyst_x_Exp[ signal_SignalRegion_nominal * signal_SignalRegion_overallNorm_x_sigma_epsilon ] = 1
//
// datasets
// --------
// RooDataSet::asimovData(obs_x_SignalRegion)
// RooDataSet::obsData(obs_x_SignalRegion)
//
// embedded datasets (in pdfs and functions)
// -----------------------------------------
// RooDataHist::signal_SignalRegionnominalDHist(obs_x_SignalRegion)
// RooDataHist::background_SignalRegionnominalDHist(obs_x_SignalRegion)
//
// named sets
// ----------
// ModelConfig_GlobalObservables:(nom_alpha_b_unc)
// ModelConfig_Observables:(obs_x_SignalRegion)
// coefList:(binWidth_obs_x_SignalRegion_0,binWidth_obs_x_SignalRegion_1)
// constraintTerms:(lumiConstraint,alpha_b_uncConstraint)
// globalObservables:(nom_alpha_b_unc)
// likelihoodTerms:(SignalRegion_model)
// obsAndWeight:(weightVar,obs_x_SignalRegion)
// observables:(obs_x_SignalRegion)
// observablesSet:(obs_x_SignalRegion)
// shapeList:(L_x_signal_SignalRegion_overallSyst_x_Exp,L_x_background_SignalRegion_overallSyst_x_Exp)
//
// generic objects
// ---------------
// RooStats::ModelConfig::ModelConfig
//
// Setting Parameter(s) of Interest as: mu
//
// === Using the following for ModelConfig ===
// Observables:             RooArgSet:: = (obs_x_SignalRegion)
// Parameters of Interest:  RooArgSet:: = (mu)
// Nuisance Parameters:     RooArgSet:: = (alpha_b_unc)
// Global Observables:      RooArgSet:: = (nom_alpha_b_unc)
// PDF:                     RooProdPdf::model_SignalRegion[ lumiConstraint * alpha_b_uncConstraint * SignalRegion_model(obs_x_SignalRegion) ] = 2
// Opening File to hold channel: _SignalRegion_CountingModel_model.root
// About to write channel measurement to file
// Writing sample: signal
// Writing sample: background
// Saved all histograms
// Saved Measurement
// Successfully wrote channel to file
//
//
// ---------------
// ---------------- Doing SignalRegion Fit
// ---------------
//
//
// [#1] INFO:Minization -- p.d.f. provides expected number of events, including extended term in likelihood.
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Minization -- createNLL: caching constraint set under name CONSTR_OF_PDF_model_SignalRegion_FOR_OBS_obs_x_SignalRegion with 2 entries
// [#1] INFO:Minization --  Including the following constraint terms in minimization: (lumiConstraint,alpha_b_uncConstraint)
// [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_model_SignalRegion_obsData_with_constr) Summation contains a RooNLLVar, using its error level
// [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
// [#1] INFO:Minization --  The following expressions have been identified as constant and will be precalculated and cached: (signal_SignalRegion_nominal,background_SignalRegion_nominal)
//  **********
//  **    1 **SET PRINT           1
//  **********
//  **********
//  **    2 **SET NOGRAD
//  **********
//  PARAMETER DEFINITIONS:
//     NO.   NAME         VALUE      STEP SIZE      LIMITS
//      1 alpha_b_unc   0.00000e+00  1.00000e+00   -5.00000e+00  5.00000e+00
//      2 mu           1.00000e+00  5.00000e-01    0.00000e+00  3.00000e+01
//  **********
//  **    3 **SET ERR         0.5
//  **********
//  **********
//  **    4 **SET PRINT           1
//  **********
//  **********
//  **    5 **SET STR           1
//  **********
//  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
//  **********
//  **    6 **MIGRAD        1000           1
//  **********
//  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
//  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
//  FCN=-5.14932 FROM MIGRAD    STATUS=INITIATE        8 CALLS           9 TOTAL
//                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
//   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  alpha_b_unc   0.00000e+00   1.00000e+00   2.01358e-01  -2.50366e-01
//    2  mu           1.00000e+00   5.00000e-01   9.60526e-02  -2.69258e+00
//                                ERR DEF= 0.5
//  MIGRAD MINIMIZATION HAS CONVERGED.
//  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
//  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
//  FCN=-5.36571 FROM MIGRAD    STATUS=CONVERGED      29 CALLS          30 TOTAL
//                      EDM=1.67853e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  alpha_b_unc   1.29121e-03   9.93344e-01   3.33974e-04   6.42529e-03
//    2  mu           1.99969e+00   1.71937e+00   3.87346e-04  -4.59793e-04
//                                ERR DEF= 0.5
//  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
//   1.000e+00 -1.001e-01
//  -1.001e-01  3.010e+00
//  PARAMETER  CORRELATION COEFFICIENTS
//        NO.  GLOBAL      1      2
//         1  0.05768   1.000 -0.058
//         2  0.05768  -0.058  1.000
//  **********
//  **    7 **SET ERR         0.5
//  **********
//  **********
//  **    8 **SET PRINT           1
//  **********
//  **********
//  **    9 **HESSE        1000
//  **********
//  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
//  FCN=-5.36571 FROM HESSE     STATUS=OK             10 CALLS          40 TOTAL
//                      EDM=1.67855e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                INTERNAL      INTERNAL
//   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
//    1  alpha_b_unc   1.29121e-03   9.93346e-01   6.67948e-05   2.58242e-04
//    2  mu           1.99969e+00   1.71937e+00   7.74692e-05  -1.04852e+00
//                                ERR DEF= 0.5
//  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
//   1.000e+00 -1.001e-01
//  -1.001e-01  3.010e+00
//  PARAMETER  CORRELATION COEFFICIENTS
//        NO.  GLOBAL      1      2
//         1  0.05771   1.000 -0.058
//         2  0.05771  -0.058  1.000
//  **********
//  **   10 **MINOS        1000           1
//  **********
//  FCN=-5.36571 FROM MINOS     STATUS=SUCCESSFUL     25 CALLS          65 TOTAL
//                      EDM=1.67855e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                  PARABOLIC         MINOS ERRORS
//   NO.   NAME      VALUE            ERROR      NEGATIVE      POSITIVE
//    1  alpha_b_unc   1.29121e-03   9.93346e-01  -1.00129e+00   9.98710e-01
//    2  mu           1.99969e+00   1.71937e+00
//                                ERR DEF= 0.5
//  **********
//  **   11 **MINOS        1000           2
//  **********
//  FCN=-5.36571 FROM MINOS     STATUS=SUCCESSFUL     47 CALLS         112 TOTAL
//                      EDM=1.67855e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                  PARABOLIC         MINOS ERRORS
//   NO.   NAME      VALUE            ERROR      NEGATIVE      POSITIVE
//    1  alpha_b_unc   1.29121e-03   9.93346e-01  -1.00129e+00   9.98710e-01
//    2  mu           1.99969e+00   1.71937e+00  -1.42015e+00   2.08261e+00
//                                ERR DEF= 0.5
// [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
// printing results for mu at 1.99969 high -1.42015 low 2.08261
// [#1] INFO:Minization -- p.d.f. provides expected number of events, including extended term in likelihood.
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Minization -- createNLL picked up cached consraints from workspace with 2 entries
// [#1] INFO:Minization --  Including the following constraint terms in minimization: (lumiConstraint,alpha_b_uncConstraint)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(lumiConstraint_Int[Lumi,nominalLumi]) using numeric integrator RooIntegrator1D to calculate Int(nominalLumi)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(alpha_b_uncConstraint_Int[alpha_b_unc,nom_alpha_b_unc]) using numeric integrator RooIntegrator1D to calculate Int(nom_alpha_b_unc)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Minization -- RooProfileLL::evaluate(nll_model_SignalRegion_obsData_with_constr_Profile[mu]) Creating instance of MINUIT
// [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_model_SignalRegion_obsData_with_constr) Summation contains a RooNLLVar, using its error level
// [#1] INFO:Minization -- RooProfileLL::evaluate(nll_model_SignalRegion_obsData_with_constr_Profile[mu]) determining minimum likelihood for current configurations w.r.t all observable
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(lumiConstraint_Int[Lumi,nominalLumi]) using numeric integrator RooIntegrator1D to calculate Int(nominalLumi)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(alpha_b_uncConstraint_Int[alpha_b_unc,nom_alpha_b_unc]) using numeric integrator RooIntegrator1D to calculate Int(nom_alpha_b_unc)
// [#1] INFO:Minization -- RooProfileLL::evaluate(nll_model_SignalRegion_obsData_with_constr_Profile[mu]) minimum found at (mu=1.99987)
// ............................................................................................................................................................................................................
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(lumiConstraint_Int[Lumi,nominalLumi]) using numeric integrator RooIntegrator1D to calculate Int(nominalLumi)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(alpha_b_uncConstraint_Int[alpha_b_unc,nom_alpha_b_unc]) using numeric integrator RooIntegrator1D to calculate Int(nom_alpha_b_unc)
// Info in <TCanvas::Print>: eps file _SignalRegion_CountingModel_profileLR.eps has been created
// full list of observables:
// RooArgList:: = (obs_x_SignalRegion)
//
//
// ------------------
//  Entering combination
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::nom_alpha_b_unc
// -----------------------------------------
// create toy data for SignalRegion
// RooDataSet::AsimovData0[obs_x_SignalRegion,channelCat,weight:binWeightAsimov] = 1 entries (2 weighted)
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing dataset asimovDataFullModel
// [#1] INFO:ObjectHandling -- RooWorkSpace::import(combined) changing name of dataset from  asimovDataFullModel to asimovData
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::obs_x_SignalRegion
// Merging data for channel SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing dataset SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkSpace::import(combined) changing name of dataset from  SignalRegion to obsData
//
// RooWorkspace(combined) combined contents
//
// variables
// ---------
// (channelCat,nom_alpha_b_unc,obs_x_SignalRegion,weightVar)
//
// datasets
// --------
// RooDataSet::asimovData(obs_x_SignalRegion,weightVar,channelCat)
// RooDataSet::obsData(channelCat,obs_x_SignalRegion)
//
// named sets
// ----------
// ModelConfig_GlobalObservables:(nom_alpha_b_unc)
// ModelConfig_Observables:(obs_x_SignalRegion,weightVar,channelCat)
// globalObservables:(nom_alpha_b_unc)
// observables:(obs_x_SignalRegion,weightVar,channelCat)
//
//
//
// ----------------
//  Importing combined model
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing dataset signal_SignalRegionnominalDHist
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing dataset background_SignalRegionnominalDHist
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooSimultaneous::simPdf
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) using existing copy of RooCategory::channelCat for import of RooSimultaneous::simPdf
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooProdPdf::model_SignalRegion
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooGaussian::lumiConstraint
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooConstVar::0.001
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::Lumi
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::nominalLumi
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooGaussian::alpha_b_uncConstraint
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooConstVar::1
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::alpha_b_unc
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) using existing copy of RooRealVar::nom_alpha_b_unc for import of RooSimultaneous::simPdf
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealSumPdf::SignalRegion_model
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooProduct::L_x_signal_SignalRegion_overallSyst_x_Exp
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooProduct::signal_SignalRegion_overallSyst_x_Exp
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooHistFunc::signal_SignalRegion_nominal
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) using existing copy of RooRealVar::obs_x_SignalRegion for import of RooSimultaneous::simPdf
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooProduct::signal_SignalRegion_overallNorm_x_sigma_epsilon
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::mu
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooConstVar::signal_SignalRegion_epsilon
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::binWidth_obs_x_SignalRegion_0
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooProduct::L_x_background_SignalRegion_overallSyst_x_Exp
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooProduct::background_SignalRegion_overallSyst_x_Exp
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooHistFunc::background_SignalRegion_nominal
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooStats::HistFactory::FlexibleInterpVar::background_SignalRegion_epsilon
// [#1] INFO:ObjectHandling -- RooWorkspace::import(combined) importing RooRealVar::binWidth_obs_x_SignalRegion_1
// setting Lumi constant
// Setting Parameter(s) of Interest as: mu
//
// === Using the following for ModelConfig ===
// Observables:             RooArgSet:: = (obs_x_SignalRegion,weightVar,channelCat)
// Parameters of Interest:  RooArgSet:: = (mu)
// Nuisance Parameters:     RooArgSet:: = (alpha_b_unc)
// Global Observables:      RooArgSet:: = (nom_alpha_b_unc)
// PDF:                     RooSimultaneous::simPdf[ indexCat=channelCat SignalRegion=model_SignalRegion ] = 2
//
// Writing combined workspace to file: _combined_CountingModel_model.root
// Writing combined measurement to file: _combined_CountingModel_model.root
// Writing sample: signal
// Writing sample: background
// Saved all histograms
// Saved Measurement
//
//
// ---------------
// ---------------- Doing combined Fit
// ---------------
//
//
// [#1] INFO:Minization -- p.d.f. provides expected number of events, including extended term in likelihood.
// [#1] INFO:Minization -- createNLL: caching constraint set under name CONSTR_OF_PDF_simPdf_FOR_OBS_channelCat:obs_x_SignalRegion with 2 entries
// [#1] INFO:Minization --  Including the following constraint terms in minimization: (lumiConstraint,alpha_b_uncConstraint)
// [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_simPdf_obsData_with_constr) Summation contains a RooNLLVar, using its error level
// [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
// RooAbsTestStatistic::initSimMode: creating slave calculator #0 for state SignalRegion (1 dataset entries)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Fitting -- RooAbsTestStatistic::initSimMode: created 1 slave calculators.
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Minization --  The following expressions have been identified as constant and will be precalculated and cached: (signal_SignalRegion_nominal,background_SignalRegion_nominal)
//  **********
//  ** 1857 **SET NOGRAD
//  **********
//  PARAMETER DEFINITIONS:
//     NO.   NAME         VALUE      STEP SIZE      LIMITS
//      1 alpha_b_unc   0.00000e+00  1.00000e+00   -5.00000e+00  5.00000e+00
//      2 mu           1.00000e+00  5.00000e-01    0.00000e+00  3.00000e+01
//  **********
//  ** 1858 **SET ERR         0.5
//  **********
//  **********
//  ** 1859 **SET PRINT           1
//  **********
//  **********
//  ** 1860 **SET STR           1
//  **********
//  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
//  **********
//  ** 1861 **MIGRAD        1000           1
//  **********
//  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
//  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
//  FCN=-5.14932 FROM MIGRAD    STATUS=INITIATE        8 CALLS           9 TOTAL
//                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
//   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  alpha_b_unc   0.00000e+00   1.00000e+00   2.01358e-01  -2.50366e-01
//    2  mu           1.00000e+00   5.00000e-01   9.60526e-02  -2.69258e+00
//                                ERR DEF= 0.5
//  MIGRAD MINIMIZATION HAS CONVERGED.
//  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
//  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
//  FCN=-5.36571 FROM MIGRAD    STATUS=CONVERGED      29 CALLS          30 TOTAL
//                      EDM=1.67853e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  alpha_b_unc   1.29121e-03   9.93344e-01   3.33974e-04   6.42529e-03
//    2  mu           1.99969e+00   1.71937e+00   3.87346e-04  -4.59793e-04
//                                ERR DEF= 0.5
//  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
//   1.000e+00 -1.001e-01
//  -1.001e-01  3.010e+00
//  PARAMETER  CORRELATION COEFFICIENTS
//        NO.  GLOBAL      1      2
//         1  0.05768   1.000 -0.058
//         2  0.05768  -0.058  1.000
//  **********
//  ** 1862 **SET ERR         0.5
//  **********
//  **********
//  ** 1863 **SET PRINT           1
//  **********
//  **********
//  ** 1864 **HESSE        1000
//  **********
//  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
//  FCN=-5.36571 FROM HESSE     STATUS=OK             10 CALLS          40 TOTAL
//                      EDM=1.67855e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                INTERNAL      INTERNAL
//   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
//    1  alpha_b_unc   1.29121e-03   9.93346e-01   6.67948e-05   2.58242e-04
//    2  mu           1.99969e+00   1.71937e+00   7.74692e-05  -1.04852e+00
//                                ERR DEF= 0.5
//  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
//   1.000e+00 -1.001e-01
//  -1.001e-01  3.010e+00
//  PARAMETER  CORRELATION COEFFICIENTS
//        NO.  GLOBAL      1      2
//         1  0.05771   1.000 -0.058
//         2  0.05771  -0.058  1.000
//  **********
//  ** 1865 **MINOS        1000           1
//  **********
//  FCN=-5.36571 FROM MINOS     STATUS=SUCCESSFUL     25 CALLS          65 TOTAL
//                      EDM=1.67855e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                  PARABOLIC         MINOS ERRORS
//   NO.   NAME      VALUE            ERROR      NEGATIVE      POSITIVE
//    1  alpha_b_unc   1.29121e-03   9.93346e-01  -1.00129e+00   9.98710e-01
//    2  mu           1.99969e+00   1.71937e+00  -1.42015e+00   2.08261e+00
//                                ERR DEF= 0.5
//  **********
//  ** 1866 **MINOS        1000           2
//  **********
//  FCN=-5.36571 FROM MINOS     STATUS=SUCCESSFUL     47 CALLS         112 TOTAL
//                      EDM=1.67855e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                  PARABOLIC         MINOS ERRORS
//   NO.   NAME      VALUE            ERROR      NEGATIVE      POSITIVE
//    1  alpha_b_unc   1.29121e-03   9.93346e-01  -1.00129e+00   9.98710e-01
//    2  mu           1.99969e+00   1.71937e+00  -1.42015e+00   2.08261e+00
//                                ERR DEF= 0.5
// [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
// printing results for mu at 1.99969 high -1.42015 low 2.08261
// [#1] INFO:Minization -- p.d.f. provides expected number of events, including extended term in likelihood.
// [#1] INFO:Minization -- createNLL picked up cached consraints from workspace with 2 entries
// [#1] INFO:Minization --  Including the following constraint terms in minimization: (lumiConstraint,alpha_b_uncConstraint)
// RooAbsTestStatistic::initSimMode: creating slave calculator #0 for state SignalRegion (1 dataset entries)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Fitting -- RooAbsTestStatistic::initSimMode: created 1 slave calculators.
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(lumiConstraint_Int[Lumi,nominalLumi]) using numeric integrator RooIntegrator1D to calculate Int(nominalLumi)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(alpha_b_uncConstraint_Int[alpha_b_unc,nom_alpha_b_unc]) using numeric integrator RooIntegrator1D to calculate Int(nom_alpha_b_unc)
// [#1] INFO:Minization -- RooProfileLL::evaluate(nll_simPdf_obsData_with_constr_Profile[mu]) Creating instance of MINUIT
// [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_simPdf_obsData_with_constr) Summation contains a RooNLLVar, using its error level
// [#1] INFO:Minization -- RooProfileLL::evaluate(nll_simPdf_obsData_with_constr_Profile[mu]) determining minimum likelihood for current configurations w.r.t all observable
// RooAbsTestStatistic::initSimMode: creating slave calculator #0 for state SignalRegion (1 dataset entries)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Fitting -- RooAbsTestStatistic::initSimMode: created 1 slave calculators.
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(lumiConstraint_Int[Lumi,nominalLumi]) using numeric integrator RooIntegrator1D to calculate Int(nominalLumi)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(alpha_b_uncConstraint_Int[alpha_b_unc,nom_alpha_b_unc]) using numeric integrator RooIntegrator1D to calculate Int(nom_alpha_b_unc)
// [#1] INFO:Minization -- RooProfileLL::evaluate(nll_simPdf_obsData_with_constr_Profile[mu]) minimum found at (mu=1.99987)
// ............................................................................................................................................................................................................
// RooAbsTestStatistic::initSimMode: creating slave calculator #0 for state SignalRegion (1 dataset entries)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:Fitting -- RooAbsTestStatistic::initSimMode: created 1 slave calculators.
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(SignalRegion_model_Int[obs_x_SignalRegion]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_SignalRegion)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(lumiConstraint_Int[Lumi,nominalLumi]) using numeric integrator RooIntegrator1D to calculate Int(nominalLumi)
// [#1] INFO:NumericIntegration -- RooRealIntegral::init(alpha_b_uncConstraint_Int[alpha_b_unc,nom_alpha_b_unc]) using numeric integrator RooIntegrator1D to calculate Int(nom_alpha_b_unc)
// Info in <TCanvas::Print>: eps file _combined_CountingModel_profileLR.eps has been created
